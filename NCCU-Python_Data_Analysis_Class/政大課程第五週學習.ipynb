# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
mydata = np.random.randn(4, 3)

# %%
mydata
# Out:
# array([[-2.1334765 ,  1.28058644, -0.80161019],
#        [ 1.71759317, -0.71840743, -0.61669703],
#        [ 0.47873889,  0.55546091,  0.13013231],
#        [ 0.81586148,  0.99184849, -0.2771094 ]])

# %%
list('ABCDE')
# Out:
# ['A', 'B', 'C', 'D', 'E']

# %%
list('甲乙丙丁')
# Out:
# ['甲', '乙', '丙', '丁']

# %%
df1= pd.DataFrame(mydata, columns=list('ABC'))

# %%
df1
# Out:
#           A         B         C
# 0 -2.133476  1.280586 -0.801610
# 1  1.717593 -0.718407 -0.616697
# 2  0.478739  0.555461  0.130132
# 3  0.815861  0.991848 -0.277109

# %%
df2 = pd.DataFrame(np.random.randn(3, 3), columns=list('ABC'))

# %%
df2
# Out:
#           A         B         C
# 0  0.448259 -0.223436  0.707675
# 1  1.539941  0.772898  0.887835
# 2  0.489921  0.461296 -2.802354

# %%
df3 = pd.concat([df1, df2], axis=0)

# %%
df3
# Out:
#           A         B         C
# 0 -2.133476  1.280586 -0.801610
# 1  1.717593 -0.718407 -0.616697
# 2  0.478739  0.555461  0.130132
# 3  0.815861  0.991848 -0.277109
# 0  0.448259 -0.223436  0.707675
# 1  1.539941  0.772898  0.887835
# 2  0.489921  0.461296 -2.802354

# %%
df3.index = range(7)

# %%
df3
# Out:
#           A         B         C
# 0 -2.133476  1.280586 -0.801610
# 1  1.717593 -0.718407 -0.616697
# 2  0.478739  0.555461  0.130132
# 3  0.815861  0.991848 -0.277109
# 4  0.448259 -0.223436  0.707675
# 5  1.539941  0.772898  0.887835
# 6  0.489921  0.461296 -2.802354

# %%
df4 = pd.concat([df1, df2], axis=1)

# %%
df4
# Out:
#           A         B         C         A         B         C
# 0 -2.133476  1.280586 -0.801610  0.448259 -0.223436  0.707675
# 1  1.717593 -0.718407 -0.616697  1.539941  0.772898  0.887835
# 2  0.478739  0.555461  0.130132  0.489921  0.461296 -2.802354
# 3  0.815861  0.991848 -0.277109       NaN       NaN       NaN

# %%
df = pd.read_csv('http://bit.ly/uforeports')

# %%
df.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
df_State = df.groupby('State').count()

# %%
df_State
# Out:
#        City  Colors Reported  Shape Reported  Time
# State
# AK      116               25              99   116
# AL      193               21             173   193
# AR      206               26             186   206
# AZ      736              145             644   738
# CA     2525              457            2148  2529
# CO      367               60             322   367
# CT      225               25             188   225
# Ca        1                0               1     1
# DE       43                5              38    43
# FL      835              120             727   837
# Fl        4                1               0     4
# GA      325               44             294   325
# HI       85               16              74    85
# IA      162               28             142   162
# ID      130               12             109   130
# IL      612              112             540   613
# IN      326               49             296   326
# KS      176               33             144   176
# KY      244               34             220   244
# LA      172               16             148   174
# MA      322               50             276   322
# MD      215               34             185   215
# ME      181               28             153   181
# MI      590               78             504   591
# MN      254               40             223   254
# MO      448               86             386   448
# MS      139               17             126   139
# MT      143               22             114   144
# NC      356               55             325   356
# ND       51                5              43    51
# NE      101                7              89   101
# NH      124               20             113   125
# NJ      370               51             326   370
# NM      241               28             193   241
# NV      281               45             236   284
# NY      913              123             823   914
# OH      665               93             605   667
# OK      193               22             167   193
# OR      534               89             414   534
# PA      598               97             519   598
# RI       67                8              62    67
# SC      166               22             148   166
# SD       57               10              39    57
# TN      286               41             247   286
# TX     1025              138             923  1027
# UT      193               36             172   193
# VA      299               51             253   299
# VT       44                6              34    44
# WA     1320              269             925  1322
# WI      357               63             312   357
# WV      131               13             112   132
# WY       69                6              57    69

# %%
df_State.sort_values(by='Time', ascending=False, inplace=True)

# %%
df_State.head(10)
# Out:
#        City  Colors Reported  Shape Reported  Time
# State
# CA     2525              457            2148  2529
# WA     1320              269             925  1322
# TX     1025              138             923  1027
# NY      913              123             823   914
# FL      835              120             727   837
# AZ      736              145             644   738
# OH      665               93             605   667
# IL      612              112             540   613
# PA      598               97             519   598
# MI      590               78             504   591

# %%
df_State[:10].Time.plot(kind='bar')

# %%
df = pd.DataFrame(np.random.randn(5,3),
                 index = range(1,6),
                 columns = list('ABC'))

# %%
df
# Out:
#           A         B         C
# 1 -0.393905  0.233080 -0.402283
# 2 -1.143660  0.358840 -0.395398
# 3  1.214924  1.160338 -0.342317
# 4  0.212499  1.328006  0.168089
# 5 -2.695820  0.840011 -0.082942

# %%
df[df.A>0]
# Out:
#           A         B         C
# 3  1.214924  1.160338 -0.342317
# 4  0.212499  1.328006  0.168089

# %%
df.loc[2, 'B']
# Out:
# 0.35884001996136417

# %%
df.loc[2, 'B'] = 1

# %%
df
# Out:
#           A         B         C
# 1 -0.393905  0.233080 -0.402283
# 2 -1.143660  1.000000 -0.395398
# 3  1.214924  1.160338 -0.342317
# 4  0.212499  1.328006  0.168089
# 5 -2.695820  0.840011 -0.082942

# %%
df.loc[df.A>0, 'C']=0

# %%
df
# Out:
#           A         B         C
# 1 -0.393905  0.233080 -0.402283
# 2 -1.143660  1.000000 -0.395398
# 3  1.214924  1.160338  0.000000
# 4  0.212499  1.328006  0.000000
# 5 -2.695820  0.840011 -0.082942

# %%
import pandas_datareader.data as web

# %%
df = web.DataReader('AAPL', 'yahoo', start = '2012-9-1', end = '2017-8-31')

# %%
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2012-08-31  95.321426  95.514282  93.892860  95.034286  85.557686  84580300
# 2012-09-04  95.108574  96.448570  94.928574  96.424286  86.809074  91973000
# 2012-09-05  96.510002  96.621429  95.657143  95.747147  86.199463  84093800
# 2012-09-06  96.167145  96.898575  95.828575  96.610001  86.976288  97799100
# 2012-09-07  96.864288  97.497147  96.538574  97.205711  87.512573  82416600

# %%
P = df['Adj Close']

# %%
P.plot()

# %%
r = P.diff()/P

# %%
r[-100:].plot()

# %%
P.rolling(window=20).mean()
# Out:
# Date
# 2012-08-31           NaN
# 2012-09-04           NaN
# 2012-09-05           NaN
# 2012-09-06           NaN
# 2012-09-07           NaN
# 2012-09-10           NaN
# 2012-09-11           NaN
# 2012-09-12           NaN
# 2012-09-13           NaN
# 2012-09-14           NaN
# 2012-09-17           NaN
# 2012-09-18           NaN
# 2012-09-19           NaN
# 2012-09-20           NaN
# 2012-09-21           NaN
# 2012-09-24           NaN
# 2012-09-25           NaN
# 2012-09-26           NaN
# 2012-09-27           NaN
# 2012-09-28     87.552710
# 2012-10-01     87.515090
# 2012-10-02     87.427249
# 2012-10-03     87.435095
# 2012-10-04     87.374196
# 2012-10-05     87.195105
# 2012-10-08     87.037106
# 2012-10-09     86.878011
# 2012-10-10     86.692296
# 2012-10-11     86.339384
# 2012-10-12     85.943453
#                  ...
# 2017-07-21    145.318384
# 2017-07-24    145.606711
# 2017-07-25    145.950123
# 2017-07-26    146.432984
# 2017-07-27    146.667716
# 2017-07-28    146.956539
# 2017-07-31    147.190277
# 2017-08-01    147.515328
# 2017-08-02    148.162948
# 2017-08-03    148.800147
# 2017-08-04    149.406081
# 2017-08-07    150.088439
# 2017-08-08    150.810497
# 2017-08-09    151.570768
# 2017-08-10    151.975713
# 2017-08-11    152.425247
# 2017-08-14    152.967051
# 2017-08-15    153.570235
# 2017-08-16    154.094386
# 2017-08-17    154.498338
# 2017-08-18    154.887827
# 2017-08-21    155.172550
# 2017-08-22    155.553055
# 2017-08-23    155.907793
# 2017-08-24    156.371075
# 2017-08-25    156.916354
# 2017-08-28    157.580058
# 2017-08-29    158.249996
# 2017-08-30    158.590008
# 2017-08-31    159.040315
# Name: Adj Close, Length: 1258, dtype: float64

# %%
P.plot()
P.rolling(window=20).mean().plot()
P.rolling(window=60).mean().plot()
